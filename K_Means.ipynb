# %%
import numpy as np
import PIL
from sklearn.cluster import KMeans
import cv2

# %%
ls
# Out:
# HDF5_intro.ipynb              Nearest_Neighbor_tf.ipynb
# K_Means.ipynb                 Tensorflow_intro.ipynb
# Logistic_regression_tf.ipynb  mytestfile.hdf5
# MNIST Tutorial-1.ipynb        sample_data/
# MNIST_data/

# %%
cd sample_data/
# Out:
# /Users/Maghav/Desktop/MAIA_work/MAIA_code/sample_data

# %%
I = np.asarray(PIL.Image.open('004.jpg'))
I = np.reshape(np.ravel(I),(len(I)*len(I[0]),3))

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(I)

# %%
temp = np.zeros((np.shape(I)))

# %%
for i in range(len(I)):
    if(kmeans.labels_[i]==0):
        temp[i][0] = 255
        temp[i][1] = 0
        temp[i][2] = 0
    elif(kmeans.labels_[i]==1):
        temp[i][0] = 0
        temp[i][1] = 0
        temp[i][2] = 255
    elif(kmeans.labels_[i]==2):
        temp[i][0] = 0
        temp[i][1] = 255
        temp[i][2] = 0

# %%
temp2 = np.asarray(PIL.Image.open('004.jpg'))

# %%
temp = np.reshape(np.ravel(temp),(np.shape(temp2)))

# %%
im = PIL.Image.fromarray(np.uint8(temp))

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=512x1321 at 0x1102F1DA0>

# %%
im.save("004_k3.jpg")

# %%
im2 = PIL.Image.fromarray(np.uint8(temp2))
im2
# Out:
# <PIL.Image.Image image mode=RGB size=512x1321 at 0x114276A90>
